# %% [markdown]
# https://doi.org/10.48550/arXiv.1007.0886

# %%
import sys
sys.path.append("../../")
DATA_PATH = "../../data/"
SAVE_PATH = "../../plots"

import matplotlib.pyplot as plt
import numpy as np
import py_common.utility as utility

# %% [markdown]
# # Hyperfine

# %%
data = np.loadtxt(f'{DATA_PATH}/hifi_single.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::]);

# %%
data = np.loadtxt(f'{DATA_PATH}/hifi_double.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::]);

# %%
data = np.loadtxt(f'{DATA_PATH}/simple_abm.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::]);
