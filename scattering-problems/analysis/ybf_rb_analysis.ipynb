# %%
import sys
sys.path.append("../../")
DATA_PATH = "../../data/"
SAVE_PATH = "../../plots"

import abm_py as abm
import matplotlib.pyplot as plt
import numpy as np
import py_common.utility as utility
from py_common.units import *

# %%
fig, ax = utility.plot()

data = utility.load(f"{DATA_PATH}/YbF_levels_proj_1.dat")
for i in range(1, data.shape[1]):
    ax.scatter(data[:, 0], data[:, i], color = "red")
    
data = utility.load(f"{DATA_PATH}/YbF_levels_uncoupled.dat")
ax.plot(data[:, 0], data[:, 1:], color = "blue")

ax.set_ylim(0.482, 0.486)
# ax.set_ylim(-0.005, 0.005)
ax.set_xlim(0, 70)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Energy [cm$^{-1}$]");

# %%
fig, ax = utility.plot()

data = utility.load(f"{DATA_PATH}/YbF_levels_proj_1.dat")
for i in range(1, data.shape[1]):
    ax.scatter(data[:, 0], data[:, i], color = "red")
    
data = utility.load(f"{DATA_PATH}/YbF_levels_uncoupled.dat")
ax.plot(data[:, 0], data[:, 1:], color = "blue")

ax.set_ylim(-0.005, 0.005)
ax.set_xlim(0, 70)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Energy [cm$^{-1}$]");
