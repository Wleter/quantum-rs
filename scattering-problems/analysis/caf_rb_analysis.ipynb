# %%
import sys
sys.path.append("../../")
DATA_PATH = "../../data/"
SAVE_PATH = "../../plots"

import abm_py as abm
import matplotlib.pyplot as plt
import numpy as np
import py_common.utility as utility
from py_common.units import *

# %%
rb = abm.HifiProblemBuilder(1, 3)
rb.with_hyperfine_coupling(6.83 / 2. * GHZ)

mag_fields = np.linspace(0, 2000, 500)
states = np.array(rb.build().states_range(mag_fields)) / GHZ

fig, ax = utility.plot()
ax.plot(mag_fields, states - states[0, 0])
ax.set_ylim(-3, 9)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Energy [GHz]");

# %%
caf = abm.HifiProblemBuilder(1, 1)
caf.with_hyperfine_coupling(120. * MHZ)

mag_fields = np.linspace(0, 100, 500)
states = np.array(caf.build().states_range(mag_fields)) / GHZ

fig, ax = utility.plot()
ax.plot(mag_fields, states - states[0, 0])
ax.set_ylim(-0.15, 0.25)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Energy [GHz]");

# %%
data = utility.load(f"{DATA_PATH}/caf_rb_levels.dat")

fig, ax = utility.plot()
# ax.plot(data[:, 0], data[:, 1] - data[0, 1], color = "deepskyblue", label="coupled rep")
# ax.plot(data[:, 0], data[:, 2:] - data[0, 1], color = "deepskyblue")

data = utility.load(f"{DATA_PATH}/caf_rb_levels_uncoupled.dat")
ax.plot(data[:, 0], data[:, 1] - data[0, 1], color = "red", label="uncoupled rep")
ax.plot(data[:, 0], data[:, 2:] - data[0, 1], color = "red")

ax.set_ylim(20.4, 20.8)
ax.set_xlim(0, 100)
ax.set_xticks([0, 50, 100])
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Energy [GHz]")
ax.legend();

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_iso.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1:] / CMINV)
ax.set_ylim(-1200, 100)
ax.set_xlim(6, 20)
ax.legend(["triplet", "singlet", "anisotropic"])
ax.set_xlabel("Distance [bohr]")
ax.set_ylabel("Energy [cm$^{-1}$]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_1chan_scatterings.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1:])
ax.set_ylim(-100, 300)
ax.legend(["triplet", "singlet"])
ax.set_xlabel("Potential mutliplication factor")
ax.set_ylabel("Scattering length [bohr]");

# %% [markdown]
# https://journals.aps.org/prresearch/pdf/10.1103/PhysRevResearch.5.023184

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_0.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_1.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_0.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_2.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %% [markdown]
# # Rotor Calculation

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_potentials_0_0.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1:] / CMINV)
ax.set_ylim(-400, 100)
ax.set_xlabel("Distance [bohr]")
ax.set_ylabel("Energy [cm$^{-1}$]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_0.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_0.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 500)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_1.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 500)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %%
data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_2.dat")

fig, ax = utility.plot()
ax.plot(data[:, 0], data[:, 1])
ax.plot(data[:, 0], data[:, 2], linestyle="--")
ax.set_ylim(-100, 200)
ax.set_xlabel("Magnetic field [G]")
ax.set_ylabel("Scattering length [bohr]");

# %% [markdown]
# # Comparison

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 200)
ax3.set_xlabel("Magnetic field [G]")
ax3.set_ylabel("Scattering length [bohr]")
ax4.set_xlabel("Magnetic field [G]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_1.dat")
ax2.plot(data[:, 0], data[:, 1])
ax2.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_0.dat")
ax3.plot(data[:, 0], data[:, 1])
ax3.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_2.dat")
ax4.plot(data[:, 0], data[:, 1])
ax4.set_title("$a_s = 242 a_0, a_t = -47 a_0$");

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 200)
ax3.set_xlabel("Magnetic field [G]")
ax3.set_ylabel("Scattering length [bohr]")
ax4.set_xlabel("Magnetic field [G]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_1.dat")
ax2.plot(data[:, 0], data[:, 1])
ax2.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_0.dat")
ax3.plot(data[:, 0], data[:, 1])
ax3.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_2.dat")
ax4.plot(data[:, 0], data[:, 1])
ax4.set_title("$a_s = 242 a_0, a_t = -47 a_0$");

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 200)
ax3.set_xlabel("Magnetic field [G]")
ax3.set_ylabel("Scattering length [bohr]")
ax4.set_xlabel("Magnetic field [G]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_uncoupled_scatterings_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_uncoupled_scatterings_1_1.dat")
ax2.plot(data[:, 0], data[:, 1])
ax2.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_uncoupled_scatterings_1_0.dat")
ax3.plot(data[:, 0], data[:, 1])
ax3.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_uncoupled_scatterings_0_2.dat")
ax4.plot(data[:, 0], data[:, 1])
ax4.set_title("$a_s = 242 a_0, a_t = -47 a_0$");

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 200)
ax2.set_xlabel("Magnetic field [G]")
ax2.set_ylabel("Scattering length [bohr]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$");

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_0.dat")
ax2.plot(data[:, 0], data[:, 1]);

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 500)
ax2.set_xlabel("Magnetic field [G]")
ax2.set_ylabel("Scattering length [bohr]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_1.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_1.dat")
ax2.plot(data[:, 0], data[:, 1]);

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 500)
ax2.set_xlabel("Magnetic field [G]")
ax2.set_ylabel("Scattering length [bohr]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_1_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_1_0.dat")
ax2.plot(data[:, 0], data[:, 1]);

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-100, 200)
ax2.set_xlabel("Magnetic field [G]")
ax2.set_ylabel("Scattering length [bohr]")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_iso_scatterings_0_2.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = 242 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_scatterings_0_2.dat")
ax2.plot(data[:, 0], data[:, 1]);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-500, 500)
ax3.set_xlabel(r"$N_\text{max}$")
ax3.set_ylabel("Scattering length [bohr]")
ax4.set_xlabel(r"$N_\text{max}$")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_1_1.dat")
ax2.plot(data[:, 0], data[:, 1])
ax2.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_1_0.dat")
ax3.plot(data[:, 0], data[:, 1])
ax3.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_0_2.dat")
ax4.plot(data[:, 0], data[:, 1])
ax4.set_title("$a_s = 242 a_0, a_t = -47 a_0$");

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True) # type: ignore
ax1.set_ylim(-500, 500)
ax3.set_xlabel(r"$N_\text{max}$")
ax3.set_ylabel("Scattering length [bohr]")
ax4.set_xlabel(r"$N_\text{max}$")
ax1.set_ylabel("Scattering length [bohr]")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_uncoupled_0_0.dat")
ax1.plot(data[:, 0], data[:, 1])
ax1.set_title("$a_s = -79 a_0, a_t = -47 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_uncoupled_1_1.dat")
ax2.plot(data[:, 0], data[:, 1])
ax2.set_title("$a_s = 71 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_uncoupled_1_0.dat")
ax3.plot(data[:, 0], data[:, 1])
ax3.set_title("$a_s = -79 a_0, a_t = 86 a_0$")

data = utility.load(f"{DATA_PATH}/CaF_Rb_n_max_uncoupled_0_2.dat")
ax4.plot(data[:, 0], data[:, 1])
ax4.set_title("$a_s = 242 a_0, a_t = -47 a_0$");
